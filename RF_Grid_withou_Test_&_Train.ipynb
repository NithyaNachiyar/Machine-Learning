# %% [markdown]
# <a href="https://colab.research.google.com/github/NithyaNachiyar/Machine-Learning/blob/main/RF_Grid_withou_Test_%26_Train.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
dataset= pd.read_csv('insurance_pre.csv')

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset, dtype=int, drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
indep=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
dep=dataset[['charges']]

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
param_grid={'criterion': ['squared_error', 'absolute_error', 'friedman_mse', 'poisson'], 'n_estimators':[100,200,300,400,500], 'max_features': ['sqrt', 'log2', 'auto']}
grid=GridSearchCV(RandomForestRegressor(), param_grid, n_jobs=-1, verbose=3, refit=True )
grid.fit(indep,dep)
# Out:
# Fitting 5 folds for each of 60 candidates, totalling 300 fits
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:540: FitFailedWarning:
# 100 fits failed out of a total of 300.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 100 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 666, in _validate_params
# ...

# %%
re=grid.cv_results_
print('The R_ Score for the best parameter {}:'.format(grid.best_params_))
# Out:
# The R_ Score for the best parameter {'criterion': 'squared_error', 'max_features': 'sqrt', 'n_estimators': 300}:

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.578441      0.144778         0.034353        0.010512
# 1        1.071690      0.302727         0.047608        0.012785
# 2        1.694170      0.417470         0.072641        0.021088
# 3        1.980559      0.526883         0.074054        0.023555
# 4        1.977892      0.012312         0.079659        0.009337
# 5        0.395805      0.007847         0.020468        0.002178
# 6        1.050338      0.205500         0.048974        0.010945
# 7        1.902098      0.390758         0.064608        0.022039
# 8        1.591037      0.014259         0.063504        0.002465
# 9        2.107317      0.239329         0.091243        0.024639
# 10       0.001602      0.000066         0.000000        0.000000
# 11       0.001586      0.000049         0.000000        0.000000
# 12       0.001494      0.000071         0.000000        0.000000
# ...

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age:40
# BMI:49
# Children:0
# Sex Male 0 or 1:1
# Smoker Yes 0 or 1:1

# %%
Furture_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print('Furture_Prediction={}'.format(Furture_Prediction))
# Out:
# Furture_Prediction=[40622.14990293]
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
