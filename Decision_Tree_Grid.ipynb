# %% [markdown]
# <a href="https://colab.research.google.com/github/NithyaNachiyar/Machine-Learning/blob/main/Decision_Tree_Grid.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
dataset=pd.read_csv('insurance_pre.csv')

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset, dtype=int, drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
indep= dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
dep=dataset[['charges']]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(indep, dep, test_size=0.30, random_state=0)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
param_grid= {'criterion':['squared_error', 'friedman_mse', 'absolute_error', 'poisson'],'splitter':['best', 'random'], 'max_features':[1.0,'sqrt','log2']}
grid=GridSearchCV(DecisionTreeRegressor(), param_grid, n_jobs=-1, refit=True, verbose=3)
grid.fit(X_train, Y_train)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson'],
#                          'max_features': [1.0, 'sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
re=grid.cv_results_
grid_prediction=grid.predict(X_test)
from sklearn.metrics import r2_score
r_score=r2_score(Y_test,grid_prediction)

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.016130      0.000703         0.009627        0.002799
# 1        0.013993      0.001214         0.005846        0.002785
# 2        0.012750      0.005156         0.005000        0.000993
# 3        0.009846      0.005430         0.004494        0.000623
# 4        0.007358      0.001267         0.004823        0.001258
# 5        0.005735      0.000205         0.004272        0.000527
# 6        0.007861      0.000289         0.004238        0.000097
# 7        0.006385      0.000255         0.005160        0.002033
# 8        0.007323      0.001261         0.005255        0.002387
# 9        0.005884      0.000134         0.004148        0.000108
# 10       0.006608      0.000189         0.004278        0.000115
# 11       0.005797      0.000195         0.004404        0.000245
# 12       0.046091      0.012943         0.008426        0.003274
# 13       0.022802      0.004189         0.004688        0.000280
# 14       0.017378      0.001085         0.004659        0.000092
# 15       0.015447      0.002634         0.005858        0.002504
# 16       0.019785      0.002836         0.006666        0.001401
# 17       0.014965      0.000930         0.004977        0.000274
# 18       0.009081      0.000710         0.004189        0.000325
# 19       0.006936      0.000141         0.004118        0.000239
# 20       0.007294      0.000420         0.005414        0.001944
# 21       0.006818      0.000511         0.004462        0.000315
# 22       0.007588      0.000223         0.004423        0.000308
# 23       0.006637      0.000168         0.004158        0.000290
#
#    param_criterion param_max_features param_splitter  \
# 0    squared_error                1.0           best
# 1    squared_error                1.0         random
# 2    squared_error               sqrt           best
# 3    squared_error               sqrt         random
# 4    squared_error               log2           best
# 5    squared_error               log2         random
# 6     friedman_mse                1.0           best
# 7     friedman_mse                1.0         random
# 8     friedman_mse               sqrt           best
# 9     friedman_mse               sqrt         random
# 10    friedman_mse               log2           best
# 11    friedman_mse               log2         random
# 12  absolute_error                1.0           best
# 13  absolute_error                1.0         random
# 14  absolute_error               sqrt           best
# 15  absolute_error               sqrt         random
# 16  absolute_error               log2           best
# 17  absolute_error               log2         random
# 18         poisson                1.0           best
# 19         poisson                1.0         random
# 20         poisson               sqrt           best
# 21         poisson               sqrt         random
# 22         poisson               log2           best
# 23         poisson               log2         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.748798
# 1   {'criterion': 'squared_error', 'max_features':...           0.698807
# 2   {'criterion': 'squared_error', 'max_features':...           0.753513
# 3   {'criterion': 'squared_error', 'max_features':...           0.720059
# 4   {'criterion': 'squared_error', 'max_features':...           0.623794
# 5   {'criterion': 'squared_error', 'max_features':...           0.361232
# 6   {'criterion': 'friedman_mse', 'max_features': ...           0.732534
# 7   {'criterion': 'friedman_mse', 'max_features': ...           0.674732
# 8   {'criterion': 'friedman_mse', 'max_features': ...           0.691133
# 9   {'criterion': 'friedman_mse', 'max_features': ...           0.746879
# 10  {'criterion': 'friedman_mse', 'max_features': ...           0.772968
# 11  {'criterion': 'friedman_mse', 'max_features': ...           0.656733
# 12  {'criterion': 'absolute_error', 'max_features'...           0.747230
# 13  {'criterion': 'absolute_error', 'max_features'...           0.734990
# 14  {'criterion': 'absolute_error', 'max_features'...           0.766927
# 15  {'criterion': 'absolute_error', 'max_features'...           0.678280
# 16  {'criterion': 'absolute_error', 'max_features'...           0.720352
# 17  {'criterion': 'absolute_error', 'max_features'...           0.622797
# 18  {'criterion': 'poisson', 'max_features': 1.0, ...           0.711284
# 19  {'criterion': 'poisson', 'max_features': 1.0, ...           0.726687
# 20  {'criterion': 'poisson', 'max_features': 'sqrt...           0.685802
# 21  {'criterion': 'poisson', 'max_features': 'sqrt...           0.663972
# 22  {'criterion': 'poisson', 'max_features': 'log2...           0.752301
# 23  {'criterion': 'poisson', 'max_features': 'log2...           0.611854
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.559842           0.772774           0.623065
# 1            0.702073           0.719037           0.480865
# 2            0.615359           0.620458           0.673152
# 3            0.556874           0.598861           0.585112
# 4            0.570494           0.350404           0.623640
# 5            0.479470           0.476926           0.515512
# 6            0.535655           0.765056           0.614291
# 7            0.625773           0.587924           0.593613
# 8            0.549026           0.739397           0.633643
# 9            0.551815           0.615614           0.564727
# 10           0.644537           0.681541           0.649525
# 11           0.549433           0.514241           0.509827
# 12           0.608168           0.607907           0.540761
# 13           0.713577           0.634623           0.474849
# 14           0.638642           0.473766           0.660547
# 15           0.565523           0.568275           0.566975
# 16           0.693561           0.520197           0.560687
# 17           0.492338           0.611113           0.494787
# 18           0.597365           0.711275           0.595059
# 19           0.648755           0.665278           0.654417
# 20           0.524343           0.523570           0.583864
# 21           0.602524           0.647101           0.572472
# 22           0.665752           0.669529           0.699855
# 23           0.637889           0.511959           0.527528
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.656296         0.672155        0.079087                2
# 1            0.589227         0.638002        0.091039               11
# 2            0.663480         0.665192        0.049702                5
# 3            0.608237         0.613829        0.055872               15
# 4            0.587130         0.551092        0.102469               22
# 5            0.464368         0.459502        0.052000               24
# 6            0.682926         0.666092        0.082691                4
# 7            0.666560         0.629720        0.035915               12
# 8            0.470219         0.616684        0.096869               14
# 9            0.380197         0.571846        0.118096               21
# 10           0.599900         0.669694        0.057822                3
# 11           0.718637         0.589774        0.083442               18
# 12           0.691828         0.639179        0.072212               10
# 13           0.652946         0.642197        0.091525                9
# 14           0.696678         0.647312        0.097071                7
# 15           0.566554         0.589121        0.044588               19
# 16           0.592969         0.617553        0.077021               13
# 17           0.338781         0.511963        0.102749               23
# 18           0.614577         0.645912        0.053797                8
# 19           0.628381         0.664704        0.033232                6
# 20           0.633025         0.590121        0.062913               17
# 21           0.560415         0.609297        0.040522               16
# 22           0.577069         0.672901        0.057056                1
# 23           0.597379         0.577322        0.049020               20

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age:50
# BMI:68
# Children:2
# Sex Male 0 or 1:1
# Smoker Yes 0 or 1:0

# %%
Future_Prediction=grid.predict([[age_input, bmi_input,children_input,sex_male_input,smoker_yes_input]])
print('Future Prediction Charges={}'.format(Future_Prediction))
# Out:
# Future Prediction Charges=[25333.33284]
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(

# %%
r_score
# Out:
# 0.7149418148992082
