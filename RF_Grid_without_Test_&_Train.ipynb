# %% [markdown]
# <a href="https://colab.research.google.com/github/NithyaNachiyar/Machine-Learning/blob/main/RF_Grid_without_Test_%26_Train.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
dataset= pd.read_csv('insurance_pre.csv')

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset, dtype=int, drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
indep=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
dep=dataset[['charges']]

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
param_grid={'criterion': ['squared_error', 'absolute_error', 'friedman_mse', 'poisson'], 'n_estimators':[100,200,300,400,500], 'max_features': ['sqrt', 'log2', 1.0]}
grid=GridSearchCV(RandomForestRegressor(), param_grid, n_jobs=-1, verbose=3, refit=True )
grid.fit(indep,dep)
# Out:
# Fitting 5 folds for each of 60 candidates, totalling 300 fits
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error',
#                                        'friedman_mse', 'poisson'],
#                          'max_features': ['sqrt', 'log2', 1.0],
#                          'n_estimators': [100, 200, 300, 400, 500]},
#              verbose=3)

# %%
re=grid.cv_results_
print('The R_ Score for the best parameter {}:'.format(grid.best_params_))
# Out:
# The R_ Score for the best parameter {'criterion': 'poisson', 'max_features': 'log2', 'n_estimators': 100}:

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.507702      0.099490         0.023164        0.003213
# 1        1.506042      0.115973         0.062342        0.012041
# 2        1.392136      0.290778         0.051633        0.005458
# 3        1.622437      0.010910         0.064013        0.003210
# 4        2.718416      0.742503         0.122966        0.032487
# 5        0.684072      0.144946         0.033926        0.012210
# 6        0.810251      0.006352         0.041570        0.010853
# 7        1.224229      0.012111         0.052354        0.007574
# 8        1.641756      0.051999         0.068744        0.011510
# 9        3.438926      0.174125         0.150462        0.026407
# 10       0.896195      0.189019         0.028000        0.010200
# 11       1.102670      0.005675         0.034318        0.001664
# 12       2.360395      0.524465         0.074171        0.023158
# 13       2.392209      0.404173         0.060966        0.000941
# 14       3.430233      0.967402         0.102033        0.031676
# 15       1.798653      0.477337         0.022276        0.005761
# 16       3.351991      0.710740         0.040398        0.012273
# 17       5.016238      0.954826         0.046355        0.001866
# 18       7.109009      1.052482         0.077253        0.028090
# 19       8.716795      0.957803         0.074236        0.006107
# 20       1.470330      0.017486         0.018265        0.000402
# 21       3.689302      0.754171         0.039595        0.016251
# 22       4.801417      0.748998         0.062179        0.022175
# 23       6.833313      0.844698         0.068056        0.018775
# 24       8.324572      1.080123         0.076943        0.009616
# 25       2.982892      0.641028         0.028430        0.009986
# 26       5.839561      0.785349         0.035693        0.004049
# 27       8.839486      0.747751         0.056763        0.022706
# 28      11.729762      0.472672         0.078217        0.023876
# 29      14.554696      0.368322         0.106229        0.031140
# 30       0.407418      0.013742         0.018973        0.001489
# 31       1.014425      0.263714         0.040157        0.018005
# 32       1.609837      0.324518         0.058122        0.018604
# 33       1.638866      0.020613         0.062962        0.001410
# 34       2.350470      0.467116         0.099208        0.029924
# 35       0.748235      0.090089         0.030515        0.009729
# 36       1.103949      0.351351         0.037093        0.002561
# 37       1.217995      0.021069         0.049032        0.001900
# 38       1.618905      0.022709         0.069395        0.009211
# 39       2.867749      0.463402         0.111619        0.031426
# 40       0.786161      0.165375         0.027516        0.007900
# 41       1.776628      0.343387         0.043590        0.012151
# 42       2.275863      0.581457         0.074863        0.023006
# 43       2.491814      0.455823         0.061457        0.001172
# 44       3.343507      0.769611         0.103096        0.032700
# 45       0.792385      0.172065         0.033818        0.010963
# 46       0.905527      0.009567         0.034048        0.002013
# 47       1.373365      0.020895         0.049007        0.001873
# 48       2.024150      0.354481         0.087453        0.018441
# 49       2.953814      0.751745         0.094355        0.035499
# 50       0.458534      0.012076         0.020763        0.001961
# 51       0.912336      0.011523         0.035882        0.002117
# 52       1.554603      0.312608         0.059079        0.016404
# 53       2.548551      0.701438         0.079462        0.025268
# 54       2.321773      0.092195         0.102701        0.047508
# 55       0.837996      0.168801         0.034268        0.012919
# 56       2.720390      0.299182         0.095807        0.046480
# 57       1.939507      0.181645         0.046310        0.000516
# 58       2.807406      0.592282         0.072132        0.017162
# 59       3.565981      0.863822         0.072431        0.010888
#
#    param_criterion param_max_features  param_n_estimators  \
# 0    squared_error               sqrt                 100
# 1    squared_error               sqrt                 200
# 2    squared_error               sqrt                 300
# 3    squared_error               sqrt                 400
# 4    squared_error               sqrt                 500
# 5    squared_error               log2                 100
# 6    squared_error               log2                 200
# 7    squared_error               log2                 300
# 8    squared_error               log2                 400
# 9    squared_error               log2                 500
# 10   squared_error                1.0                 100
# 11   squared_error                1.0                 200
# 12   squared_error                1.0                 300
# 13   squared_error                1.0                 400
# 14   squared_error                1.0                 500
# 15  absolute_error               sqrt                 100
# 16  absolute_error               sqrt                 200
# 17  absolute_error               sqrt                 300
# 18  absolute_error               sqrt                 400
# 19  absolute_error               sqrt                 500
# 20  absolute_error               log2                 100
# 21  absolute_error               log2                 200
# 22  absolute_error               log2                 300
# 23  absolute_error               log2                 400
# 24  absolute_error               log2                 500
# 25  absolute_error                1.0                 100
# 26  absolute_error                1.0                 200
# 27  absolute_error                1.0                 300
# 28  absolute_error                1.0                 400
# 29  absolute_error                1.0                 500
# 30    friedman_mse               sqrt                 100
# 31    friedman_mse               sqrt                 200
# 32    friedman_mse               sqrt                 300
# 33    friedman_mse               sqrt                 400
# 34    friedman_mse               sqrt                 500
# 35    friedman_mse               log2                 100
# 36    friedman_mse               log2                 200
# 37    friedman_mse               log2                 300
# 38    friedman_mse               log2                 400
# 39    friedman_mse               log2                 500
# 40    friedman_mse                1.0                 100
# 41    friedman_mse                1.0                 200
# 42    friedman_mse                1.0                 300
# 43    friedman_mse                1.0                 400
# 44    friedman_mse                1.0                 500
# 45         poisson               sqrt                 100
# 46         poisson               sqrt                 200
# 47         poisson               sqrt                 300
# 48         poisson               sqrt                 400
# 49         poisson               sqrt                 500
# 50         poisson               log2                 100
# 51         poisson               log2                 200
# 52         poisson               log2                 300
# 53         poisson               log2                 400
# 54         poisson               log2                 500
# 55         poisson                1.0                 100
# 56         poisson                1.0                 200
# 57         poisson                1.0                 300
# 58         poisson                1.0                 400
# 59         poisson                1.0                 500
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.861994
# 1   {'criterion': 'squared_error', 'max_features':...           0.860676
# 2   {'criterion': 'squared_error', 'max_features':...           0.859760
# 3   {'criterion': 'squared_error', 'max_features':...           0.858462
# 4   {'criterion': 'squared_error', 'max_features':...           0.858789
# 5   {'criterion': 'squared_error', 'max_features':...           0.857738
# 6   {'criterion': 'squared_error', 'max_features':...           0.858408
# 7   {'criterion': 'squared_error', 'max_features':...           0.858537
# 8   {'criterion': 'squared_error', 'max_features':...           0.859138
# 9   {'criterion': 'squared_error', 'max_features':...           0.858509
# 10  {'criterion': 'squared_error', 'max_features':...           0.847557
# 11  {'criterion': 'squared_error', 'max_features':...           0.847544
# 12  {'criterion': 'squared_error', 'max_features':...           0.844706
# 13  {'criterion': 'squared_error', 'max_features':...           0.847581
# 14  {'criterion': 'squared_error', 'max_features':...           0.848806
# 15  {'criterion': 'absolute_error', 'max_features'...           0.861098
# 16  {'criterion': 'absolute_error', 'max_features'...           0.858397
# 17  {'criterion': 'absolute_error', 'max_features'...           0.860357
# 18  {'criterion': 'absolute_error', 'max_features'...           0.859989
# 19  {'criterion': 'absolute_error', 'max_features'...           0.858366
# 20  {'criterion': 'absolute_error', 'max_features'...           0.858226
# 21  {'criterion': 'absolute_error', 'max_features'...           0.857982
# 22  {'criterion': 'absolute_error', 'max_features'...           0.859866
# 23  {'criterion': 'absolute_error', 'max_features'...           0.857671
# 24  {'criterion': 'absolute_error', 'max_features'...           0.859582
# 25  {'criterion': 'absolute_error', 'max_features'...           0.842882
# 26  {'criterion': 'absolute_error', 'max_features'...           0.835469
# 27  {'criterion': 'absolute_error', 'max_features'...           0.840070
# 28  {'criterion': 'absolute_error', 'max_features'...           0.838346
# 29  {'criterion': 'absolute_error', 'max_features'...           0.839359
# 30  {'criterion': 'friedman_mse', 'max_features': ...           0.856414
# 31  {'criterion': 'friedman_mse', 'max_features': ...           0.857128
# 32  {'criterion': 'friedman_mse', 'max_features': ...           0.859776
# 33  {'criterion': 'friedman_mse', 'max_features': ...           0.859857
# 34  {'criterion': 'friedman_mse', 'max_features': ...           0.858886
# 35  {'criterion': 'friedman_mse', 'max_features': ...           0.856952
# 36  {'criterion': 'friedman_mse', 'max_features': ...           0.859762
# 37  {'criterion': 'friedman_mse', 'max_features': ...           0.857933
# 38  {'criterion': 'friedman_mse', 'max_features': ...           0.859595
# 39  {'criterion': 'friedman_mse', 'max_features': ...           0.858914
# 40  {'criterion': 'friedman_mse', 'max_features': ...           0.850518
# 41  {'criterion': 'friedman_mse', 'max_features': ...           0.847925
# 42  {'criterion': 'friedman_mse', 'max_features': ...           0.849911
# 43  {'criterion': 'friedman_mse', 'max_features': ...           0.848338
# 44  {'criterion': 'friedman_mse', 'max_features': ...           0.847536
# 45  {'criterion': 'poisson', 'max_features': 'sqrt...           0.857318
# 46  {'criterion': 'poisson', 'max_features': 'sqrt...           0.856872
# 47  {'criterion': 'poisson', 'max_features': 'sqrt...           0.857672
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.838320         0.833834        0.034091               31
# 1            0.840699         0.834172        0.030736               24
# 2            0.842426         0.834318        0.029673               17
# 3            0.842002         0.834057        0.031100               28
# 4            0.842143         0.834187        0.029360               22
# 5            0.836722         0.831582        0.028348               40
# 6            0.843396         0.835387        0.029330                3
# 7            0.842084         0.834275        0.029362               19
# 8            0.841500         0.834991        0.028917                8
# 9            0.839711         0.834531        0.029280               14
# 10           0.834080         0.826832        0.030183               51
# 11           0.839123         0.827084        0.029784               48
# 12           0.839132         0.826839        0.029708               50
# 13           0.836803         0.827289        0.029420               46
# 14           0.838900         0.826766        0.030933               53
# 15           0.848951         0.833917        0.028937               29
# 16           0.840115         0.832687        0.028450               37
# 17           0.845564         0.834970        0.028947                9
# 18           0.843681         0.834316        0.028250               18
# 19           0.844836         0.834264        0.028488               20
# 20           0.842808         0.832506        0.028044               38
# 21           0.845659         0.834548        0.027965               13
# 22           0.843883         0.834359        0.028880               16
# 23           0.843194         0.833880        0.028533               30
# 24           0.844391         0.834197        0.029233               21
# 25           0.831923         0.823205        0.029631               60
# 26           0.835041         0.823637        0.027737               58
# 27           0.837483         0.825241        0.027991               56
# 28           0.836154         0.823882        0.029216               57
# 29           0.836754         0.823514        0.029427               59
# 30           0.837608         0.832103        0.031324               39
# 31           0.839426         0.833306        0.029799               34
# 32           0.839263         0.834104        0.029123               26
# 33           0.840573         0.834889        0.029944               10
# 34           0.841312         0.834753        0.028513               11
# 35           0.839589         0.833239        0.030123               35
# 36           0.840264         0.833701        0.030090               32
# 37           0.841713         0.834145        0.029753               25
# 38           0.841593         0.835180        0.029382                5
# 39           0.840628         0.835069        0.029370                7
# 40           0.838292         0.826313        0.028205               55
# 41           0.839290         0.828112        0.029781               41
# 42           0.836360         0.827535        0.029830               45
# 43           0.837176         0.827110        0.030157               47
# 44           0.837633         0.826795        0.029617               52
# 45           0.841009         0.833060        0.028705               36
# 46           0.841484         0.834524        0.029471               15
# 47           0.841202         0.834555        0.029463               12
# 48           0.841137         0.835220        0.029735                4
# 49           0.843623         0.835781        0.029473                2
# 50           0.845504         0.836027        0.029019                1
# 51           0.841387         0.835098        0.030029                6
# 52           0.840656         0.833641        0.029906               33
# 53           0.842220         0.834177        0.028427               23
# 54           0.841800         0.834099        0.029259               27
# 55           0.841140         0.827742        0.030405               42
# 56           0.840075         0.826349        0.029307               54
# 57           0.837607         0.827582        0.029582               44
# 58           0.838443         0.826907        0.030048               49
# 59           0.837917         0.827660        0.029019               43

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age:28
# BMI:59
# Children:0
# Sex Male 0 or 1:1
# Smoker Yes 0 or 1:1

# %%
Furture_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print('Furture_Prediction={}'.format(Furture_Prediction))
# Out:
# Furture_Prediction=[40834.5809249]
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
