# %% [markdown]
# <a href="https://colab.research.google.com/github/NithyaNachiyar/Machine-Learning/blob/main/For_deployment_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
dataset=pd.read_csv('insurance_pre.csv')

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset, dtype=int, drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
indep=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
dep=dataset[['charges']]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(indep,dep,test_size=0.30, random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR
grid_params={'kernel':('linear', 'poly', 'rbf', 'sigmoid'),'gamma':('scale', 'auto'),'C':[100,200,300,400,500]}
grid=GridSearchCV(SVR(), grid_params, verbose=3, n_jobs=-1,refit=True)
grid.fit(X_train, Y_train)
# Out:
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# /usr/local/lib/python3.10/dist-packages/numpy/ma/core.py:2820: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(estimator=SVR(), n_jobs=-1,
#              param_grid={'C': [100, 200, 300, 400, 500],
#                          'gamma': ('scale', 'auto'),
#                          'kernel': ('linear', 'poly', 'rbf', 'sigmoid')},
#              verbose=3)

# %%
from sklearn.metrics import r2_score
grid_prediction=grid.predict(X_test)
r_score=r2_score(Y_test, grid_prediction)
re=grid.cv_results_
print('The R_Score of the best parameter{}:'.format(grid.best_params_))
# Out:
# The R_Score of the best parameter{'C': 500, 'gamma': 'auto', 'kernel': 'poly'}:

# %%
r_score
# Out:
# 0.8263683541268956

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_C  \
# 0        0.108304      0.029824         0.012905        0.005953      100
# 1        0.128478      0.030921         0.020305        0.006376      100
# 2        0.114840      0.027334         0.031708        0.009002      100
# 3        0.186480      0.033813         0.033136        0.009203      100
# 4        0.121334      0.024517         0.014893        0.003441      100
# 5        0.073663      0.008644         0.011303        0.002224      100
# 6        0.077354      0.010610         0.024821        0.005927      100
# 7        0.113180      0.014545         0.019786        0.003947      100
# 8        0.096485      0.020659         0.012515        0.004200      200
# 9        0.086805      0.010367         0.012010        0.002364      200
# 10       0.094502      0.016905         0.020327        0.004614      200
# 11       0.113413      0.023924         0.022819        0.005889      200
# 12       0.096110      0.017422         0.011520        0.002291      200
# 13       0.101156      0.022197         0.012003        0.002743      200
# 14       0.081055      0.015393         0.019068        0.004861      200
# 15       0.090356      0.003399         0.015239        0.000436      200
# 16       0.072615      0.001381         0.008888        0.000984      300
# 17       0.078863      0.006084         0.009107        0.000143      300
# 18       0.076493      0.006809         0.017333        0.001262      300
# 19       0.099231      0.008806         0.018819        0.004198      300
# 20       0.073289      0.002430         0.008152        0.000185      300
# 21       0.084490      0.006405         0.010070        0.001381      300
# 22       0.079809      0.009269         0.019185        0.004218      300
# 23       0.100241      0.019317         0.015301        0.000802      300
# 24       0.076445      0.004079         0.008057        0.000150      400
# 25       0.077722      0.007140         0.008817        0.000266      400
# 26       0.082732      0.006465         0.018438        0.003398      400
# 27       0.113605      0.024367         0.015451        0.000742      400
# 28       0.078349      0.002905         0.008288        0.000276      400
# 29       0.075841      0.002159         0.008862        0.000100      400
# 30       0.084821      0.008376         0.016845        0.000622      400
# 31       0.105399      0.011774         0.018117        0.006146      400
# 32       0.076396      0.002433         0.008357        0.000135      500
# 33       0.078756      0.004320         0.009058        0.000121      500
# 34       0.093183      0.008551         0.020724        0.004592      500
# 35       0.107476      0.017433         0.016434        0.002502      500
# 36       0.110817      0.034300         0.010674        0.004160      500
# 37       0.077668      0.002654         0.009424        0.000722      500
# 38       0.092698      0.018437         0.019034        0.003130      500
# 39       0.085126      0.018002         0.012672        0.002605      500
#
#    param_gamma param_kernel  \
# 0        scale       linear
# 1        scale         poly
# 2        scale          rbf
# 3        scale      sigmoid
# 4         auto       linear
# 5         auto         poly
# 6         auto          rbf
# 7         auto      sigmoid
# 8        scale       linear
# 9        scale         poly
# 10       scale          rbf
# 11       scale      sigmoid
# 12        auto       linear
# 13        auto         poly
# 14        auto          rbf
# 15        auto      sigmoid
# 16       scale       linear
# 17       scale         poly
# 18       scale          rbf
# 19       scale      sigmoid
# 20        auto       linear
# 21        auto         poly
# 22        auto          rbf
# 23        auto      sigmoid
# 24       scale       linear
# 25       scale         poly
# 26       scale          rbf
# 27       scale      sigmoid
# 28        auto       linear
# 29        auto         poly
# 30        auto          rbf
# 31        auto      sigmoid
# 32       scale       linear
# 33       scale         poly
# 34       scale          rbf
# 35       scale      sigmoid
# 36        auto       linear
# 37        auto         poly
# 38        auto          rbf
# 39        auto      sigmoid
#
#                                                params  split0_test_score  \
# 0    {'C': 100, 'gamma': 'scale', 'kernel': 'linear'}           0.584474
# 1      {'C': 100, 'gamma': 'scale', 'kernel': 'poly'}           0.537117
# 2       {'C': 100, 'gamma': 'scale', 'kernel': 'rbf'}           0.301041
# 3   {'C': 100, 'gamma': 'scale', 'kernel': 'sigmoid'}           0.478930
# 4     {'C': 100, 'gamma': 'auto', 'kernel': 'linear'}           0.584474
# 5       {'C': 100, 'gamma': 'auto', 'kernel': 'poly'}           0.540643
# 6        {'C': 100, 'gamma': 'auto', 'kernel': 'rbf'}           0.300573
# 7    {'C': 100, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.478364
# 8    {'C': 200, 'gamma': 'scale', 'kernel': 'linear'}           0.595030
# 9      {'C': 200, 'gamma': 'scale', 'kernel': 'poly'}           0.694861
# 10      {'C': 200, 'gamma': 'scale', 'kernel': 'rbf'}           0.452989
# 11  {'C': 200, 'gamma': 'scale', 'kernel': 'sigmoid'}           0.501143
# 12    {'C': 200, 'gamma': 'auto', 'kernel': 'linear'}           0.595030
# 13      {'C': 200, 'gamma': 'auto', 'kernel': 'poly'}           0.696668
# 14       {'C': 200, 'gamma': 'auto', 'kernel': 'rbf'}           0.452559
# 15   {'C': 200, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.501321
# 16   {'C': 300, 'gamma': 'scale', 'kernel': 'linear'}           0.599604
# 17     {'C': 300, 'gamma': 'scale', 'kernel': 'poly'}           0.746443
# 18      {'C': 300, 'gamma': 'scale', 'kernel': 'rbf'}           0.516594
# 19  {'C': 300, 'gamma': 'scale', 'kernel': 'sigmoid'}           0.507606
# 20    {'C': 300, 'gamma': 'auto', 'kernel': 'linear'}           0.599604
# 21      {'C': 300, 'gamma': 'auto', 'kernel': 'poly'}           0.747800
# 22       {'C': 300, 'gamma': 'auto', 'kernel': 'rbf'}           0.516236
# 23   {'C': 300, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.506131
# 24   {'C': 400, 'gamma': 'scale', 'kernel': 'linear'}           0.601156
# 25     {'C': 400, 'gamma': 'scale', 'kernel': 'poly'}           0.765619
# 26      {'C': 400, 'gamma': 'scale', 'kernel': 'rbf'}           0.565576
# 27  {'C': 400, 'gamma': 'scale', 'kernel': 'sigmoid'}           0.465645
# 28    {'C': 400, 'gamma': 'auto', 'kernel': 'linear'}           0.601156
# 29      {'C': 400, 'gamma': 'auto', 'kernel': 'poly'}           0.766572
# 30       {'C': 400, 'gamma': 'auto', 'kernel': 'rbf'}           0.565221
# 31   {'C': 400, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.458798
# 32   {'C': 500, 'gamma': 'scale', 'kernel': 'linear'}           0.601152
# 33     {'C': 500, 'gamma': 'scale', 'kernel': 'poly'}           0.780516
# 34      {'C': 500, 'gamma': 'scale', 'kernel': 'rbf'}           0.601802
# 35  {'C': 500, 'gamma': 'scale', 'kernel': 'sigmoid'}           0.466661
# 36    {'C': 500, 'gamma': 'auto', 'kernel': 'linear'}           0.601152
# 37      {'C': 500, 'gamma': 'auto', 'kernel': 'poly'}           0.781613
# 38       {'C': 500, 'gamma': 'auto', 'kernel': 'rbf'}           0.601529
# 39   {'C': 500, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.434785
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.655818           0.553380           0.576939
# 1            0.579373           0.471840           0.537966
# 2            0.338741           0.174086           0.217641
# 3            0.563200           0.427152           0.451250
# 4            0.655818           0.553380           0.576939
# 5            0.575051           0.474839           0.535730
# 6            0.339474           0.173708           0.217991
# 7            0.561673           0.428331           0.450454
# 8            0.688634           0.559858           0.622351
# 9            0.706119           0.642964           0.694146
# 10           0.497218           0.352586           0.401416
# 11           0.589167           0.473766           0.479113
# 12           0.688634           0.559858           0.622351
# 13           0.704051           0.644147           0.693071
# 14           0.497868           0.352177           0.401731
# 15           0.589314           0.473825           0.484535
# 16           0.664389           0.564136           0.636520
# 17           0.755902           0.704210           0.734263
# 18           0.557954           0.428418           0.470030
# 19           0.577333           0.447263           0.497058
# 20           0.664389           0.564136           0.636520
# 21           0.754195           0.705375           0.733789
# 22           0.558519           0.428028           0.470329
# 23           0.578905           0.447255           0.490145
# 24           0.664315           0.567076           0.618422
# 25           0.770211           0.739072           0.754049
# 26           0.603861           0.484669           0.521856
# 27           0.565369           0.435357           0.446725
# 28           0.664315           0.567076           0.618422
# 29           0.769549           0.739407           0.753923
# 30           0.604353           0.484338           0.522121
# 31           0.565948           0.429700           0.448032
# 32           0.599729           0.571527           0.542915
# 33           0.780878           0.753634           0.768982
# 34           0.640415           0.534267           0.570844
# 35           0.542011           0.413211           0.459869
# 36           0.599729           0.571527           0.542915
# 37           0.780025           0.754530           0.768597
# 38           0.640750           0.533952           0.571062
# 39           0.549481           0.435040           0.430290
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.546881         0.583498        0.038787               15
# 1            0.424478         0.510155        0.054955               24
# 2            0.183403         0.242982        0.065542               40
# 3            0.432199         0.470546        0.049762               31
# 4            0.546881         0.583498        0.038787               15
# 5            0.424640         0.510181        0.053582               23
# 6            0.183375         0.243024        0.065733               39
# 7            0.431701         0.470105        0.049110               33
# 8            0.559135         0.605002        0.048034               11
# 9            0.568962         0.661411        0.051140                7
# 10           0.363565         0.413555        0.054622               38
# 11           0.466853         0.502008        0.045067               26
# 12           0.559135         0.605002        0.048034               11
# 13           0.569084         0.661404        0.050766                8
# 14           0.363539         0.413575        0.054843               37
# 15           0.466915         0.503182        0.044603               25
# 16           0.562605         0.605451        0.040040                9
# 17           0.636739         0.715511        0.043064                6
# 18           0.432136         0.481026        0.049923               30
# 19           0.479099         0.501672        0.043014               27
# 20           0.562605         0.605451        0.040040                9
# 21           0.636820         0.715596        0.042821                5
# 22           0.432111         0.481045        0.050121               29
# 23           0.479076         0.500302        0.043772               28
# 24           0.564012         0.602996        0.036909               13
# 25           0.667950         0.739380        0.037300                4
# 26           0.480887         0.531370        0.047424               22
# 27           0.439080         0.470435        0.048603               32
# 28           0.564012         0.602996        0.036909               13
# 29           0.667964         0.739483        0.037313                3
# 30           0.480871         0.531381        0.047582               21
# 31           0.434603         0.467416        0.050314               34
# 32           0.565263         0.576117        0.022025               17
# 33           0.687296         0.754261        0.034926                2
# 34           0.521863         0.573838        0.043568               19
# 35           0.428703         0.462091        0.044535               35
# 36           0.565263         0.576117        0.022025               17
# 37           0.687317         0.754417        0.034925                1
# 38           0.521847         0.573828        0.043694               20
# 39           0.425720         0.455063        0.047332               36

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age:28
# BMI:33
# Children:3
# Sex Male 0 or 1:1
# Smoker Yes 0 or 1:0

# %%
Future_Prediction=grid.predict([[age_input, bmi_input,children_input,sex_male_input,smoker_yes_input]])
print('Future Prediction Charges={}'.format(Future_Prediction))
# Out:
# Future Prediction Charges=[15724154.4983949]

# %%
r_score
# Out:
# 0.8263683541268956

# %%
import pickle
filename="Finalized_insurance_prediction.sav"

# %%
pickle.dump(grid,open(filename,'wb'))
loaded_model=pickle.load(open("Finalized_insurance_prediction.sav",'rb'))
