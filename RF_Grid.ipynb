# %% [markdown]
# <a href="https://colab.research.google.com/github/NithyaNachiyar/Machine-Learning/blob/main/RF_Grid.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
dataset= pd.read_csv('insurance_pre.csv')

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset, dtype=int, drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
indep=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
dep=dataset[['charges']]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test=train_test_split(indep, dep, random_state=0, test_size=0.30)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
param_grid={'criterion': ['squared_error', 'absolute_error', 'friedman_mse', 'poisson'], 'n_estimators':[100,200,300,400,500], 'max_features': ['sqrt', 'log2', 1.0]}
grid=GridSearchCV(RandomForestRegressor(), param_grid, n_jobs=-1, verbose=3, refit=True )
grid.fit(X_train, Y_train)
# Out:
# Fitting 5 folds for each of 60 candidates, totalling 300 fits
# /usr/local/lib/python3.10/dist-packages/numpy/ma/core.py:2820: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error',
#                                        'friedman_mse', 'poisson'],
#                          'max_features': ['sqrt', 'log2', 1.0],
#                          'n_estimators': [100, 200, 300, 400, 500]},
#              verbose=3)

# %%
re=grid.cv_results_
grid_prediction=grid.predict(X_test)
from sklearn.metrics import r2_score
r_score=r2_score(Y_test,grid_prediction)
print('The R_ Score for the best parameter {}:'.format(grid.best_params_))
# Out:
# The R_ Score for the best parameter {'criterion': 'poisson', 'max_features': 'log2', 'n_estimators': 200}:

# %%
r_score
# Out:
# 0.8717142113444956

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.728157      0.064910         0.030337        0.010156
# 1        1.156546      0.329602         0.049438        0.021072
# 2        1.470959      0.377852         0.069745        0.023138
# 3        1.978301      0.568120         0.064530        0.020427
# 4        1.701884      0.010099         0.067569        0.003909
# 5        0.342804      0.010541         0.017553        0.000769
# 6        0.690597      0.014256         0.032075        0.004643
# 7        1.470751      0.263490         0.071205        0.019353
# 8        1.802508      0.513699         0.066540        0.023358
# 9        1.695425      0.011698         0.065193        0.001941
# 10       0.444576      0.011149         0.020804        0.007827
# 11       0.913229      0.065253         0.028348        0.001100
# 12       2.315411      0.242539         0.069617        0.023993
# ...

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age:60
# BMI:55
# Children:1
# Sex Male 0 or 1:1
# Smoker Yes 0 or 1:1

# %%
Furture_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print('Furture_Prediction={}'.format(Furture_Prediction))
# Out:
# Furture_Prediction=[47013.6543655]
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
